# %%
import pandas as pd
import numpy as np

# %%
ucv8 = pd.read_csv("UCV8.csv")

# %%
ucv10 = pd.read_csv('UCV10.csv')

# %%
ucv10.head()
# Out:
#            id                                                url  region  \
# 0  7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 1  7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 2  7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 3  7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 4  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...  auburn
#
#                       region_url  price    year manufacturer  \
# 0  https://auburn.craigslist.org  33590  2014.0          gmc
# 1  https://auburn.craigslist.org  22590  2010.0    chevrolet
# 2  https://auburn.craigslist.org  39590  2020.0    chevrolet
# 3  https://auburn.craigslist.org  30990  2017.0       toyota
# 4  https://auburn.craigslist.org  15000  2013.0         ford
#
#                       model  condition    cylinders  ... drive       size  \
# 0  sierra 1500 crew cab slt       good  8 cylinders  ...   NaN        NaN
# ...

# %%
ucv10.describe(include="all")
# Out:
#                   id                                                url  \
# count   4.268530e+05                                             426853
# unique           NaN                                             426853
# top              NaN  https://inlandempire.craigslist.org/ctd/d/vict...
# freq             NaN                                                  1
# mean    7.311493e+09                                                NaN
# std     4.410556e+06                                                NaN
# min     7.207408e+09                                                NaN
# 25%     7.308145e+09                                                NaN
# 50%     7.312622e+09                                                NaN
# 75%     7.315254e+09                                                NaN
# max     7.317101e+09                                                NaN
#
#           region                      region_url         price           year  \
# ...

# %%
ucv8.columns
# Out:
# Index(['Unnamed: 0', 'id', 'url', 'region', 'region_url', 'price', 'year',
#        'manufacturer', 'model', 'condition', 'cylinders', 'fuel', 'odometer',
#        'title_status', 'transmission', 'VIN', 'drive', 'size', 'type',
#        'paint_color', 'image_url', 'description', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %%
ucv8 = ucv8.drop("Unnamed: 0",axis=1)

# %%
ucv8.describe(include="all")
# Out:
#                   id                                                url  \
# count   4.582130e+05                                             458213
# unique           NaN                                             458213
# top              NaN  https://quadcities.craigslist.org/ctd/d/waterl...
# freq             NaN                                                  1
# mean    7.235233e+09                                                NaN
# std     4.594362e+06                                                NaN
# min     7.208550e+09                                                NaN
# 25%     7.231953e+09                                                NaN
# 50%     7.236409e+09                                                NaN
# 75%     7.239321e+09                                                NaN
# max     7.241019e+09                                                NaN
#
#           region                   region_url         price           year  \
# ...

# %%
ucv10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426853 entries, 0 to 426852
# Data columns (total 25 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426853 non-null  int64
#  1   url           426853 non-null  object
#  2   region        426853 non-null  object
#  3   region_url    426853 non-null  object
#  4   price         426853 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
ucv8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458213 entries, 0 to 458212
# Data columns (total 25 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            458213 non-null  int64
#  1   url           458213 non-null  object
#  2   region        458213 non-null  object
#  3   region_url    458213 non-null  object
#  4   price         458213 non-null  int64
#  5   year          457163 non-null  float64
#  6   manufacturer  439993 non-null  object
#  7   model         453367 non-null  object
#  8   condition     265273 non-null  object
#  9   cylinders     287073 non-null  object
#  10  fuel          454976 non-null  object
#  11  odometer      402910 non-null  float64
#  12  title_status  455636 non-null  object
#  13  transmission  455771 non-null  object
#  14  VIN           270664 non-null  object
#  15  drive         324025 non-null  object
#  16  size          136865 non-null  object
# ...

# %%
pandemic_dataframes = [ucv8, ucv10]
raw_pandemic_data = pd.concat(pandemic_dataframes)
display(raw_pandemic_data)
# Out:
#                 id                                                url  \
# 0       7240372487  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1       7240309422  https://auburn.craigslist.org/cto/d/auburn-201...
# 2       7240224296  https://auburn.craigslist.org/cto/d/auburn-200...
# 3       7240103965  https://auburn.craigslist.org/cto/d/lanett-tru...
# 4       7239983776  https://auburn.craigslist.org/cto/d/auburn-200...
# ...            ...                                                ...
# 426848  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426849  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426850  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426851  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426852  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# ...

# %%
ucv2 = pd.read_csv("UCV2.csv")

# %%
ucv2.columns
# Out:
# Index(['url', 'city', 'city_url', 'price', 'year', 'manufacturer', 'make',
#        'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'desc', 'lat', 'long'],
#       dtype='object')

# %%
ucv3 = pd.read_csv("UCV3.csv")

# %%
ucv3.columns
# Out:
# Index(['url', 'city', 'city_url', 'price', 'year', 'manufacturer', 'make',
#        'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'desc', 'lat', 'long'],
#       dtype='object')

# %%
prepandemic_dataframes = [ucv2, ucv3]
raw_prepandemic_data = pd.concat(prepandemic_dataframes)
display(raw_prepandemic_data)
# Out:
#                                                       url         city  \
# 0       https://abilene.craigslist.org/cto/d/aspermont...  abilene, TX
# 1       https://abilene.craigslist.org/ctd/d/liberty-h...  abilene, TX
# 2       https://abilene.craigslist.org/ctd/d/liberty-h...  abilene, TX
# 3       https://abilene.craigslist.org/cto/d/merkel-20...  abilene, TX
# 4       https://abilene.craigslist.org/cto/d/breckenri...  abilene, TX
# ...                                                   ...          ...
# 525834  https://abilene.craigslist.org/cto/d/abilene-2...  abilene, TX
# 525835  https://abilene.craigslist.org/ctd/d/lubbock-2...  abilene, TX
# 525836  https://abilene.craigslist.org/cto/d/abilene-2...  abilene, TX
# 525837  https://abilene.craigslist.org/ctd/d/temple-su...  abilene, TX
# 525838  https://abilene.craigslist.org/cto/d/roscoe-20...  abilene, TX
#
#                               city_url  price    year manufacturer  \
# ...

# %%
ucv2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550313 entries, 0 to 550312
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   url           550313 non-null  object
#  1   city          550313 non-null  object
#  2   city_url      550313 non-null  object
#  3   price         550313 non-null  int64
#  4   year          548826 non-null  float64
#  5   manufacturer  523398 non-null  object
#  6   make          540636 non-null  object
#  7   condition     300239 non-null  object
#  8   cylinders     331316 non-null  object
#  9   fuel          545572 non-null  object
#  10  odometer      439513 non-null  float64
#  11  title_status  546289 non-null  object
#  12  transmission  546258 non-null  object
#  13  VIN           311075 non-null  object
#  14  drive         384475 non-null  object
#  15  size          184057 non-null  object
#  16  type          391134 non-null  object
# ...

# %%
ucv3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525839 entries, 0 to 525838
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   url           525839 non-null  object
#  1   city          525839 non-null  object
#  2   city_url      525839 non-null  object
#  3   price         525839 non-null  int64
#  4   year          524399 non-null  float64
#  5   manufacturer  501260 non-null  object
#  6   make          517201 non-null  object
#  7   condition     279881 non-null  object
#  8   cylinders     315439 non-null  object
#  9   fuel          521544 non-null  object
#  10  odometer      427248 non-null  float64
#  11  title_status  523014 non-null  object
#  12  transmission  521572 non-null  object
#  13  VIN           305653 non-null  object
#  14  drive         374475 non-null  object
#  15  size          174519 non-null  object
#  16  type          376906 non-null  object
# ...

# %%
raw_prepandemic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1076152 entries, 0 to 525838
# Data columns (total 22 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   url           1076152 non-null  object
#  1   city          1076152 non-null  object
#  2   city_url      1076152 non-null  object
#  3   price         1076152 non-null  int64
#  4   year          1073225 non-null  float64
#  5   manufacturer  1024658 non-null  object
#  6   make          1057837 non-null  object
#  7   condition     580120 non-null   object
#  8   cylinders     646755 non-null   object
#  9   fuel          1067116 non-null  object
#  10  odometer      866761 non-null   float64
#  11  title_status  1069303 non-null  object
#  12  transmission  1067830 non-null  object
#  13  VIN           616728 non-null   object
#  14  drive         758950 non-null   object
#  15  size          358576 non-null   object
#  16  type          768040 non-null   object
# ...

# %%
raw_pandemic_data.reset_index(drop=True, inplace=True)
raw_pandemic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885066 entries, 0 to 885065
# Data columns (total 23 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   url           885066 non-null  object
#  1   region        885066 non-null  object
#  2   region_url    885066 non-null  object
#  3   price         885066 non-null  int64
#  4   year          882838 non-null  float64
#  5   manufacturer  849227 non-null  object
#  6   model         874970 non-null  object
#  7   condition     518049 non-null  object
#  8   cylinders     536275 non-null  object
#  9   fuel          878843 non-null  object
#  10  odometer      825390 non-null  float64
#  11  title_status  874274 non-null  object
#  12  transmission  880095 non-null  object
#  13  VIN           536502 non-null  object
#  14  drive         620338 non-null  object
#  15  size          257384 non-null  object
#  16  type          679497 non-null  object
# ...

# %%
raw_prepandemic_data.insert(22,"posting_date",None)

# %%
raw_prepandemic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1076152 entries, 0 to 525838
# Data columns (total 23 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   url           1076152 non-null  object
#  1   city          1076152 non-null  object
#  2   city_url      1076152 non-null  object
#  3   price         1076152 non-null  int64
#  4   year          1073225 non-null  float64
#  5   manufacturer  1024658 non-null  object
#  6   make          1057837 non-null  object
#  7   condition     580120 non-null   object
#  8   cylinders     646755 non-null   object
#  9   fuel          1067116 non-null  object
#  10  odometer      866761 non-null   float64
#  11  title_status  1069303 non-null  object
#  12  transmission  1067830 non-null  object
#  13  VIN           616728 non-null   object
#  14  drive         758950 non-null   object
#  15  size          358576 non-null   object
#  16  type          768040 non-null   object
# ...

# %%
raw_prepandemic_data.reset_index(drop=True, inplace=True)
raw_prepandemic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1076152 entries, 0 to 1076151
# Data columns (total 23 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   url           1076152 non-null  object
#  1   city          1076152 non-null  object
#  2   city_url      1076152 non-null  object
#  3   price         1076152 non-null  int64
#  4   year          1073225 non-null  float64
#  5   manufacturer  1024658 non-null  object
#  6   make          1057837 non-null  object
#  7   condition     580120 non-null   object
#  8   cylinders     646755 non-null   object
#  9   fuel          1067116 non-null  object
#  10  odometer      866761 non-null   float64
#  11  title_status  1069303 non-null  object
#  12  transmission  1067830 non-null  object
#  13  VIN           616728 non-null   object
#  14  drive         758950 non-null   object
#  15  size          358576 non-null   object
#  16  type          768040 non-null   object
# ...

# %%
raw_prepandemic_data.tail()
# Out:
#                                                        url         city  \
# 1076147  https://abilene.craigslist.org/cto/d/abilene-2...  abilene, TX
# 1076148  https://abilene.craigslist.org/ctd/d/lubbock-2...  abilene, TX
# 1076149  https://abilene.craigslist.org/cto/d/abilene-2...  abilene, TX
# 1076150  https://abilene.craigslist.org/ctd/d/temple-su...  abilene, TX
# 1076151  https://abilene.craigslist.org/cto/d/roscoe-20...  abilene, TX
#
#                                city_url  price    year manufacturer  \
# 1076147  https://abilene.craigslist.org  11000  2002.0         jeep
# 1076148  https://abilene.craigslist.org   6500  2012.0       nissan
# 1076149  https://abilene.craigslist.org   3000  2005.0         ford
# 1076150  https://abilene.craigslist.org   8488  2011.0        honda
# 1076151  https://abilene.craigslist.org   6150  2011.0          NaN
#
#                       make  condition    cylinders fuel  ...  VIN drive  \
# ...

# %%
raw_prepandemic_data.rename(columns = {'city':'region', 'city_url':'region_url', 'make':'model','desc':'description'}, inplace=True)
raw_prepandemic_data.head()
# Out:
#                                                  url       region  \
# 0  https://abilene.craigslist.org/cto/d/aspermont...  abilene, TX
# 1  https://abilene.craigslist.org/ctd/d/liberty-h...  abilene, TX
# 2  https://abilene.craigslist.org/ctd/d/liberty-h...  abilene, TX
# 3  https://abilene.craigslist.org/cto/d/merkel-20...  abilene, TX
# 4  https://abilene.craigslist.org/cto/d/breckenri...  abilene, TX
#
#                        region_url  price    year manufacturer         model  \
# 0  https://abilene.craigslist.org   9000  2009.0    chevrolet  suburban lt2
# 1  https://abilene.craigslist.org  31999  2012.0          ram          2500
# 2  https://abilene.craigslist.org  16990  2003.0          ram          3500
# 3  https://abilene.craigslist.org   6000  2002.0          gmc   sierra 1500
# 4  https://abilene.craigslist.org  37000  2012.0    chevrolet          3500
#
#    condition    cylinders    fuel  ...                VIN drive       size  \
# ...

# %%
dataframes = [raw_prepandemic_data, raw_pandemic_data]
raw_data = pd.concat(dataframes)
display(raw_data)
# Out:
#                                                       url       region  \
# 0       https://abilene.craigslist.org/cto/d/aspermont...  abilene, TX
# 1       https://abilene.craigslist.org/ctd/d/liberty-h...  abilene, TX
# 2       https://abilene.craigslist.org/ctd/d/liberty-h...  abilene, TX
# 3       https://abilene.craigslist.org/cto/d/merkel-20...  abilene, TX
# 4       https://abilene.craigslist.org/cto/d/breckenri...  abilene, TX
# ...                                                   ...          ...
# 885061  https://wyoming.craigslist.org/ctd/d/atlanta-2...      wyoming
# 885062  https://wyoming.craigslist.org/ctd/d/atlanta-2...      wyoming
# 885063  https://wyoming.craigslist.org/ctd/d/atlanta-2...      wyoming
# 885064  https://wyoming.craigslist.org/ctd/d/atlanta-2...      wyoming
# 885065  https://wyoming.craigslist.org/ctd/d/atlanta-2...      wyoming
#
#                             region_url  price  year manufacturer  \
# ...

# %%
raw_data.reset_index(drop=True, inplace=True)
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961218 entries, 0 to 1961217
# Data columns (total 23 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   url           object
#  1   region        object
#  2   region_url    object
#  3   price         int64
#  4   year          float64
#  5   manufacturer  object
#  6   model         object
#  7   condition     object
#  8   cylinders     object
#  9   fuel          object
#  10  odometer      float64
#  11  title_status  object
#  12  transmission  object
#  13  VIN           object
#  14  drive         object
#  15  size          object
#  16  type          object
#  17  paint_color   object
#  18  image_url     object
#  19  description   object
#  20  lat           float64
#  21  long          float64
#  22  posting_date  object
# dtypes: float64(4), int64(1), object(18)
# memory usage: 344.1+ MB

# %%
raw_data.fillna({'year':0}, inplace=True)
raw_data['year'] = raw_data['year'].astype(int)
raw_data['year']
# Out:
# 0          2009
# 1          2012
# 2          2003
# 3          2002
# 4          2012
#            ...
# 1961213    2019
# 1961214    2020
# 1961215    2020
# 1961216    2018
# 1961217    2019
# Name: year, Length: 1961218, dtype: int32

# %%
raw_data['odometer'] = raw_data['odometer'].astype(int, errors='ignore')
raw_data['odometer']
# Out:
# 0         217743
# 1            nan
# 2            nan
# 3         195000
# 4         178000
#            ...
# 1961213    32226
# 1961214    12029
# 1961215     4174
# 1961216    30112
# 1961217    22716
# Name: odometer, Length: 1961218, dtype: float64

# %%
raw_data['lat'] = raw_data['lat'].astype(object)
raw_data['lat']
# Out:
# 0         33
# 1         31
# 2         31
# 3         32
# 4         33
#           ..
# 1961213   34
# 1961214   34
# 1961215   34
# 1961216   34
# 1961217   34
# Name: lat, Length: 1961218, dtype: object

# %%
raw_data['long'] = raw_data['long'].astype(object)
raw_data['long']
# Out:
# 0         -100
# 1          -98
# 2          -98
# 3         -100
# 4          -99
#           ...
# 1961213    -84
# 1961214    -84
# 1961215    -84
# 1961216    -84
# 1961217    -84
# Name: long, Length: 1961218, dtype: object

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
raw_data.describe().round(0)
# Out:
#            price    year   odometer
# count    1961218 1961218    1692151
# mean       68799    2005     101178
# std     10856876     103    1583663
# min            0       0          0
# 25%         4399    2007      44372
# 50%        10000    2012      91500
# 75%        19995    2016     136770
# max   3787876818    2022 2043755555

# %%
raw_data.max()
# Out:
# url           https://zanesville.craigslist.org/cto/d/zanesv...
# region                                   zanesville / cambridge
# region_url                    https://zanesville.craigslist.org
# price                                                3787876818
# year                                                       2022
# odometer                                             2043755555
# lat                                                          84
# long                                                        174
# dtype: object

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1961218 entries, 0 to 1961217
# Data columns (total 23 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   url           object
#  1   region        object
#  2   region_url    object
#  3   price         int64
#  4   year          int32
#  5   manufacturer  object
#  6   model         object
#  7   condition     object
#  8   cylinders     object
#  9   fuel          object
#  10  odometer      float64
#  11  title_status  object
#  12  transmission  object
#  13  VIN           object
#  14  drive         object
#  15  size          object
#  16  type          object
#  17  paint_color   object
#  18  image_url     object
#  19  description   object
#  20  lat           object
#  21  long          object
#  22  posting_date  object
# dtypes: float64(1), int32(1), int64(1), object(20)
# memory usage: 336.7+ MB
